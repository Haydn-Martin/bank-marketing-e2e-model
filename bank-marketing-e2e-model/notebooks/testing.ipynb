# %% [markdown]
# ### Fetching raw data

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
os.getenv('RAW_DATA_STORAGE_FILE')
# Out:
# './data'

# %%
# Change the working directory
os.chdir('C:\\Users\\haydn\\PycharmProjects\\bank-marketing-e2e-model\\bank-marketing-e2e-model\\src\\data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\haydn\\PycharmProjects\\bank-marketing-e2e-model\\bank-marketing-e2e-model\\src\\data'

# %%
from raw_data_gen import FetchUCIData

# %%
test_fetch = FetchUCIData(222)

# %%
test_fetch.fetch_raw_data()
# Out:
# {'data': {'ids': None,
#   'features':        age           job   marital  education default  balance housing loan  \
#   0       58    management   married   tertiary      no     2143     yes   no
#   1       44    technician    single  secondary      no       29     yes   no
#   2       33  entrepreneur   married  secondary      no        2     yes  yes
#   3       47   blue-collar   married        NaN      no     1506     yes   no
#   4       33           NaN    single        NaN      no        1      no   no
#   ...    ...           ...       ...        ...     ...      ...     ...  ...
#   45206   51    technician   married   tertiary      no      825      no   no
#   45207   71       retired  divorced    primary      no     1729      no   no
#   45208   72       retired   married  secondary      no     5715      no   no
#   45209   57   blue-collar   married  secondary      no      668      no   no
#   45210   37  entrepreneur   married  secondary      no     2971      no   no
# ...

# %%
test_fetch.format_data()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
test_fetch = FetchUCIData('sgfdg')
test_fetch.format_data()
# Out:
# Error fetching raw data: ID must be an integer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 test_fetch = FetchUCIData('sgfdg')
# ----> 2 test_fetch.format_data()
#
# File ~\PycharmProjects\bank-marketing-e2e-model\bank-marketing-e2e-model\src\data\raw_data_gen.py:30, in FetchUCIData.format_data(self)
#      28 raw_data = self.fetch_raw_data()
#      29 # Get features and targets
# ---> 30 x_vals = raw_data.data.features
#      31 y_vals = raw_data.data.targets
#      32 # Combine to one df
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
# Change the working directory
os.chdir('C:\\Users\\haydn\\PycharmProjects\\bank-marketing-e2e-model\\bank-marketing-e2e-model')

# %%
from src.data.raw_data_gen import SaveRawTrainingData

# %%
save_test = SaveRawTrainingData(FetchUCIData(222).format_data(),
                                os.getenv('RAW_DATA_STORAGE_FILE'))

# %%
save_test.save_raw_training_data()

# %% [markdown]
# ### Model training
